# %%
from math import pi

import pandas

from bokeh.plotting import figure,show,output_file

# %%
df = pandas.read_html('https://coinmarketcap.com/currencies/bitcoin/historical-data/?start=20190220&end=20190320')[0][::-1]

# %%
df['Date'] = pandas.to_datetime(df['Date'])

# %%
df.rename(index = str,columns = {'Open*':'Open'},inplace = True)
df.rename(index = str,columns = {'Close**':'Close'},inplace = True)

# %% [markdown]
# 將欄位的名稱重新設為其他欄位名稱。

# %%
df
# Out:
#          Date     Open     High      Low    Close       Volume   Market Cap
# 28 2019-02-20  3946.68  4000.49  3926.25  3999.82   8693373948  70194350042
# 27 2019-02-21  4000.26  4010.01  3940.11  3954.12   7775128102  69398333876
# 26 2019-02-22  3952.41  4006.54  3950.82  4005.53   7826525254  70308555857
# 25 2019-02-23  3998.92  4166.29  3968.73  4142.53   8922258316  72720867208
# 24 2019-02-24  4145.46  4210.64  3793.71  3810.43  10794227451  66897483404
# 23 2019-02-25  3807.00  3913.71  3807.00  3882.70   9318796067  68173204651
# 22 2019-02-26  3878.70  3891.58  3837.99  3854.36   7931218996  67683296223
# 21 2019-02-27  3857.48  3888.80  3787.06  3851.05   8301309684  67631949500
# 20 2019-02-28  3848.26  3906.06  3845.82  3854.79   8399767798  67704774107
# 19 2019-03-01  3853.76  3907.80  3851.69  3859.58   7661247975  67796965743
# 18 2019-03-02  3855.32  3874.61  3832.13  3864.42   7578786076  67888255371
# 17 2019-03-03  3862.27  3875.48  3836.91  3847.18   7253558152  67592376373
# 16 2019-03-04  3845.09  3867.38  3733.75  3761.56   9029175788  66094551587
# 15 2019-03-05  3759.83  3903.92  3745.18  3896.38  10174126415  68470655400
# 14 2019-03-06  3897.08  3919.51  3871.46  3903.94   9175291529  68609885776
# 13 2019-03-07  3903.38  3939.37  3894.11  3911.48   9584165519  68749421311
# 12 2019-03-08  3913.23  3950.43  3875.23  3901.13  10638638944  68574579320
# 11 2019-03-09  3894.55  3987.24  3892.39  3963.31  10796103518  69674508655
# 10 2019-03-10  3966.17  3966.17  3924.38  3951.60   9713267607  69475297370
# 9  2019-03-11  3953.74  3966.38  3889.24  3905.23  10125901903  68666928025
# 8  2019-03-12  3903.76  3926.89  3863.56  3909.16   9809887079  68743000581
# 7  2019-03-13  3913.05  3926.60  3891.90  3906.72   9469184841  68706700381
# 6  2019-03-14  3905.58  3946.50  3901.30  3924.37  10480789570  69024696307
# 5  2019-03-15  3926.66  3968.54  3914.02  3960.91   9394210605  69675002377
# 4  2019-03-16  3963.90  4077.04  3961.66  4048.73   9856166973  71227967573
# 3  2019-03-17  4047.72  4054.12  4006.41  4025.23   8221625400  70821939585
# 2  2019-03-18  4029.97  4071.56  4009.12  4032.51   9646954186  70958165407
# 1  2019-03-19  4032.69  4082.22  4023.81  4071.19   9344919956  71647703828
# 0  2019-03-20  4070.79  4089.46  4031.11  4087.48  10175916388  71942444088

# %%
# 判斷開始跟結束的價錢，來設定顏色
# 當結束價錢大於開始價錢就是白色
# 當結束價錢小於開始價錢就是紅色
inc = df.Close > df.Open
dec = df.Open > df.Close

# %%
# 設定寬度
w = 12 * 60 * 60 * 1000

# %%
# 設定圖表的互動工具
tools = 'pan,wheel_zoom,box_zoom,reset,save'

# %%
p = figure(x_axis_type = 'datetime',tools = tools, plot_width = 1200, title = 'Bitcoin Candlesticks')

# %%
# 設定x軸轉向的角度
p.xaxis.major_label_orientation = pi / 4

# %%
# 設定圖表的格線，小寫的 alpha 會讓格線將近看不到
# 大小的 ALPHA 會讓格線特別明顯
p.grid.grid_line_alpha = 0.3

# %%
# 提供最高跟最低的座標給圖表
p.segment(df.Date, df.High, df.Date, df.Low, color = 'black')

p.vbar(df.Date[inc], w, df.Open[inc], df.Close[inc] , fill_color = '#DES10D', line_color = "black")
p.vbar(df.Date[dec], w, df.Open[dec], df.Close[dec] , fill_color = '#F2583E', line_color = 'black')
# Out:
# GlyphRenderer(id='1046', ...)

# %%
output_file('bitcoin.html',title = 'Bitcoin Candlesticks')

# %%
show(p)
